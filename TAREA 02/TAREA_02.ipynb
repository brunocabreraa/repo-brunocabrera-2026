# %%
# Problema 1
for i in range (-30, 51):
  if i < 0:
    print(i, "muy frío")
  elif i <=24:
    print(i, "templado")
  else:
    print(i, "caluroso")


# Problema 2
for i in range (1,101):
  if i % 5 == 0:
    if i % 10 == 0:
      print (i, "bip bip")
    else:
      print(i, "bip")


# Problema 3

p1 = int(input("escribe tu primer puntaje:"))
p2 = int(input("escribe tu segundo puntaje:"))
s = p1 + p2

if s < 50:
  print("tu nivel es principiante")
elif s < 80:
  print("tu nivel es intermedio")
else:
  print("tu nivel es pro")

# Problema 4

edad = int(input("Ingresa tu edad:"))
le_gusta_musica = input("¿te gusta la música? (sí/no):").lower()
le_gusta_bailar = input("te gusta bailar? (sí/no):").lower()

if edad >= 18 and le_gusta_musica == "sí" and le_gusta_bailar == "sí":print("eres una estrella de la fiesta")
elif le_gusta_musica == "sí" and le_gusta_bailar == "no":print("te gusta la música, pero no tanto bailar")
else:print("tienes tu propio estilo")
